# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read image
img = cv.imread('test.png')
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()

# %%
# haar_cascade cat face classifier
cascade_classifier = cv.CascadeClassifier('haar_catface.xml')

# %%
# Read video
capture = cv.VideoCapture('../data_test/cat_video.mp4')

while True:
    isTrue, frame = capture.read()
    cv.imshow('Video', frame)

    if cv.waitKey(1) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-b1c89f13faec> in <module>
#       4 while True:
#       5     isTrue, frame = capture.read()
# ----> 6     cv.imshow('Video', frame)
#       7
#       8     if cv.waitKey(1) & 0xFF == ord('d'):
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
# Read video
capture = cv.VideoCapture('../data_test/cat_video.mp4')

while True:
    isTrue, frame = capture.read()
    cv.imshow('Video', frame)
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    detections = cascade_classifier.detectMultiScale(gray, 1.3, 5)
    

    if cv.waitKey(1) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-e18914f0dac0> in <module>
#       6     cv.imshow('Video', frame)
#       7     gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# ----> 8     detections = cascade_classifier.detectMultiScale(gray, 1.3, 5)
#       9
#      10
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv.VideoCapture('../data_test/cat_video.mp4')

while True:

    ret, frame = cap.read()
    frame = cv.cvtColor(frame, 0)
    detections = cascade_classifier.detectMultiScale(frame, 1.3, 5)

    if (len(detections)>0):
        (x,y,w,h) = detections[0]
        frame = cv.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)

    cv.imshow('frame',frame)
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-c89d42b4919a> in <module>
#       5     ret, frame = cap.read()
#       6     frame = cv.cvtColor(frame, 0)
# ----> 7     detections = cascade_classifier.detectMultiScale(frame, 1.3, 5)
#       8
#       9     if (len(detections)>0):
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
while capture.isOpened():
    playing, frame = capture.read()

    if playing and frame_count % sample_rate == 0:
        img, cats, cats_ext, eyes = detect_cat(frame)
        """
        We'll ignore cat for now. I'm not 100% sure on this,
        but I think the cat_ext seems to do a better job on
        detecting a good cat. 
        """
        if len(cats_ext) > 0:
            cat_detected += 1
            save_image(img, cats, cats_ext, eyes, f"test_output/cat_detected_{frame_count}")
            x, y, w, h = cats[0]
            crop_img = img[y:y+h, x:x+w]

            gray_image = cv2.cvtColor(crop_img, cv2.COLOR_BGR2GRAY)        
            laplacian_var_face.append(
                cv2.Laplacian(gray_image, ddepth=3, ksize=3).var()
            )
            laplacian_var_face_x.append(frame_count)

        if len(eyes) > 0:
            eyes_detected.append(eyes.shape[0])

        gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        laplacian_var.append(
            cv2.Laplacian(gray_image, ddepth=3, ksize=3).var()
        )

    if not playing:
        break

    frame_count += 1

capture.release()

# %%
img = cv.imread('../data_test/cat2.JPG')
cv.imshow('Cat', img)


gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray Person', gray)

haar_cascade = cv.CascadeClassifier('haar_catface.xml')

faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=1)

print(f'Number of cat faces found = {len(faces_rect)}')


for (x,y,w,h) in faces_rect:
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=3)

cv.imshow('Detected Cat Faces', img)



cv.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-1daf5b1eca8f> in <module>
#       8 haar_cascade = cv.CascadeClassifier('haar_catface.xml')
#       9
# ---> 10 faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=1)
#      11
#      12 print(f'Number of cat faces found = {len(faces_rect)}')
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
image = cv.imread('../data_test/cat2.JPG')
cv.imshow("test", image)

# wait forever, if Q is pressed then close cv image window
if cv.waitKey(0) & 0xFF == ord('q'):
    cv.destroyAllWindows()

# %%
cv.destroyAllWindows()

# %%
img = cv.imread('../data_test/cat2.JPG')

cv.imshow('image',img)
k = cv.waitKey(0) & 0xFF
if k == 27:         # wait for ESC key to exit
    cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-45bc61b80482> in <module>
#       1 img = cv.imread('../data_test/cat2.JPG')
#       2
# ----> 3 cv.imshow('image',img)
#       4 k = cv.waitKey(0) & 0xFF
#       5 if k == 27:         # wait for ESC key to exit
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
# BGR to RGB
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# # haar_cascade cat face classifier
# cascade_classifier = cv.CascadeClassifier('haar_catface.xml')
# faces_rect = cascade_classifier.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=1)
# print(f'Number of cat faces found = {len(faces_rect)}')


# for (x,y,w,h) in faces_rect:
#     cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=3)


# Default color in matplotlib is RGB
plt.imshow(rgb)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-351c7e6ecbc5> in <module>
#       1 # BGR to RGB
# ----> 2 rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
#       3 gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#       4
#       5 # # haar_cascade cat face classifier
#
# error: OpenCV(4.5.1) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
